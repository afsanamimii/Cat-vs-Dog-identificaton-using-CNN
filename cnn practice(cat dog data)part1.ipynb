# %%
import numpy as np
import cv2
import os
import random
import matplotlib.pyplot as plt
import pickle

# %%
#data preprocessing

# %%
DIRECTORY=r"C:\Users\Asus\own_dataset"
CATAGORIES=['cat','dog']

# %%
IMG_SIZE=100
data= []
for catagories in CATAGORIES:
    folder=os.path.join(DIRECTORY,catagories)
    label= CATAGORIES.index(catagories)
    
    for img in os.listdir(folder):
        img_path=os.path.join(folder,img)
        img_arr=cv2.imread(img_path) #read image in the form of an array
        img_arr=cv2.resize(img_arr,(IMG_SIZE,IMG_SIZE))
        plt.imshow( img_arr)
        data.append([img_arr,label])
# Out:
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8

# %%
len(data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-8bc3cadd9feb> in <module>
#       1 len(data)
# ----> 2 data.dtype
#
# AttributeError: 'list' object has no attribute 'dtype'

# %%
random.shuffle(data)

# %%
data[2] #mixing up data
# Out:
# [array([[[18, 16, 15],
#          [18, 16, 15],
#          [20, 18, 17],
#          ...,
#          [16, 14, 14],
#          [16, 14, 14],
#          [16, 14, 14]],
#
#         [[16, 14, 13],
#          [16, 14, 13],
#          [20, 18, 17],
#          ...,
#          [16, 14, 14],
#          [16, 14, 14],
#          [16, 14, 14]],
#
#         [[13, 11, 10],
#          [16, 14, 13],
#          [18, 16, 15],
#          ...,
#          [16, 14, 14],
#          [16, 14, 14],
#          [16, 14, 14]],
#
#         ...,
#
#         [[ 9,  9,  9],
#          [ 9,  9,  9],
#          [11, 11, 11],
#          ...,
#          [43, 48, 63],
#          [61, 66, 81],
#          [67, 72, 87]],
#
#         [[ 9,  9,  9],
#          [ 9,  9,  9],
#          [ 9,  9,  9],
#          ...,
#          [48, 53, 68],
#          [60, 62, 73],
#          [69, 71, 82]],
#
#         [[ 9,  9,  9],
#          [ 9,  9,  9],
#          [ 9,  9,  9],
#          ...,
#          [47, 56, 70],
#          [61, 66, 74],
#          [78, 81, 89]]], dtype=uint8),
#  0]

# %%
X=[]
Y=[]

for features,lebels in data:
    X.append(features)
    Y.append(lebels)

# %%
X=np.array(X)
Y=np.array(Y)

# %%
len(Y)
len(X)
# Out:
# 67

# %%
pickle.dump(X,open('feature.pkl','wb'))
pickle.dump(Y,open('lebel.pkl','wb'))

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-ab0a5b0d7958> in <module>
# ----> 1 data.dtype
#
# AttributeError: 'list' object has no attribute 'dtype'
