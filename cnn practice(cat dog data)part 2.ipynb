# %%
import pickle
from keras.preprocessing.image import ImageDataGenerator
# Out:
# Using TensorFlow backend.

# %%
x=pickle.load(open('feature.pkl','rb'))

# %%
y=pickle.load(open('lebel.pkl','rb'))

# %%
x
# Out:
# array([[[[120,  28,   9],
#          [122,  30,  11],
#          [124,  32,  12],
#          ...,
#          [ 89,  19,   6],
#          [ 90,  20,   7],
#          [ 91,  21,   8]],
#
#         [[124,  30,  11],
#          [125,  31,  12],
#          [127,  33,  14],
#          ...,
#          [ 92,  20,   8],
#          [ 92,  20,   8],
#          [ 93,  21,   9]],
#
#         [[128,  33,  13],
#          [129,  34,  15],
#          [130,  35,  16],
#          ...,
#          [ 91,  17,   5],
#          [ 92,  19,   6],
#          [ 94,  20,   8]],
#
#         ...,
#
#         [[128, 144, 150],
#          [133, 148, 156],
#          [129, 144, 152],
#          ...,
#          [128, 141, 151],
#          [102, 114, 123],
#          [107, 119, 128]],
#
#         [[122, 139, 142],
#          [ 96, 112, 117],
#          [101, 117, 124],
#          ...,
#          [131, 151, 162],
#          [124, 142, 154],
#          [106, 122, 131]],
#
#         [[120, 135, 138],
#          [ 76,  90,  96],
#          [ 72,  85,  93],
#          ...,
#          [135, 151, 163],
#          [128, 142, 154],
#          [120, 130, 141]]],
#
#
#        [[[ 57,  62,  61],
#          [ 57,  62,  61],
#          [ 55,  60,  59],
#          ...,
#          [ 61,  63,  63],
#          [ 62,  64,  64],
#          [ 62,  64,  64]],
#
#         [[ 57,  62,  61],
#          [ 57,  62,  61],
#          [ 55,  60,  59],
#          ...,
#          [ 61,  63,  63],
#          [ 62,  64,  64],
#          [ 62,  64,  64]],
#
#         [[ 57,  62,  61],
#          [ 57,  62,  61],
#          [ 54,  60,  58],
#          ...,
#          [ 63,  64,  64],
#          [ 62,  64,  64],
#          [ 62,  64,  64]],
#
#         ...,
#
#         [[169, 175, 182],
#          [163, 169, 176],
#          [158, 164, 171],
#          ...,
#          [ 70,  83,  96],
#          [ 67,  78,  88],
#          [ 66,  76,  84]],
#
#         [[161, 167, 179],
#          [165, 171, 183],
#          [164, 170, 182],
#          ...,
#          [ 67,  84,  98],
#          [ 68,  83,  96],
#          [ 79,  93, 103]],
#
#         [[144, 151, 166],
#          [150, 157, 172],
#          [150, 158, 172],
#          ...,
#          [ 66,  85, 100],
#          [ 76,  94, 107],
#          [ 74,  90, 102]]],
#
#
#        [[[  7,   7,   7],
#          [  7,   7,   7],
#          [  8,   8,   8],
#          ...,
#          [ 38,  41,  44],
#          [184, 176, 157],
#          [136, 125, 121]],
#
#         [[  7,   7,   7],
#          [  7,   7,   7],
#          [  7,   7,   7],
#          ...,
#          [ 44,  47,  48],
#          [185, 177, 155],
#          [138, 128, 121]],
#
#         [[  7,   7,   7],
#          [  7,   7,   7],
#          [  6,   6,   6],
#          ...,
#          [ 49,  50,  48],
#          [173, 169, 145],
#          [137, 128, 119]],
#
#         ...,
#
#         [[ 15,  21,  22],
#          [ 15,  19,  20],
#          [ 14,  14,  16],
#          ...,
#          [ 58,  57,  53],
#          [ 54,  51,  47],
#          [ 18,  20,  20]],
#
#         [[ 15,  20,  21],
#          [ 16,  20,  21],
#          [ 16,  16,  18],
#          ...,
#          [ 59,  58,  54],
#          [ 58,  55,  50],
#          [ 16,  21,  20]],
#
#         [[ 15,  20,  21],
#          [ 16,  20,  21],
#          [ 17,  17,  19],
#          ...,
#          [ 55,  54,  50],
#          [ 55,  52,  47],
#          [ 16,  22,  21]]],
#
#
#        ...,
#
#
#        [[[209, 138,  97],
#          [228, 171, 141],
#          [229, 161, 114],
#          ...,
#          [159, 170, 183],
#          [173, 175, 181],
#          [180, 179, 183]],
#
#         [[208, 145,  89],
#          [231, 179, 139],
#          [209, 149, 103],
#          ...,
#          [153, 157, 168],
#          [190, 181, 184],
#          [188, 192, 193]],
#
#         [[247, 188, 125],
#          [240, 184, 130],
#          [234, 178, 127],
#          ...,
#          [102, 103, 113],
#          [106,  98, 103],
#          [ 88,  96, 100]],
#
#         ...,
#
#         [[207, 206, 216],
#          [207, 206, 216],
#          [207, 207, 217],
#          ...,
#          [215, 213, 219],
#          [212, 210, 216],
#          [214, 212, 218]],
#
#         [[208, 207, 216],
#          [201, 200, 209],
#          [207, 207, 216],
#          ...,
#          [217, 217, 223],
#          [213, 212, 218],
#          [209, 208, 214]],
#
#         [[207, 206, 215],
#          [210, 209, 218],
#          [211, 210, 219],
#          ...,
#          [210, 210, 216],
#          [214, 214, 220],
#          [210, 210, 216]]],
#
#
#        [[[ 50,  60,  70],
#          [ 52,  63,  71],
#          [ 58,  70,  74],
#          ...,
#          [ 14,  26,  30],
#          [ 27,  32,  37],
#          [ 31,  25,  37]],
#
#         [[ 40,  49,  58],
#          [ 42,  52,  59],
#          [ 52,  64,  66],
#          ...,
#          [ 13,  24,  28],
#          [ 27,  31,  36],
#          [ 35,  33,  39]],
#
#         [[ 42,  50,  57],
#          [ 38,  47,  51],
#          [ 43,  53,  53],
#          ...,
#          [ 20,  29,  33],
#          [ 33,  36,  41],
#          [ 35,  35,  41]],
#
#         ...,
#
#         [[ 45,  54,  74],
#          [ 60,  68, 105],
#          [ 68,  75, 118],
#          ...,
#          [ 98, 109, 139],
#          [100, 113, 145],
#          [104, 115, 153]],
#
#         [[ 50,  57,  77],
#          [ 64,  68, 106],
#          [ 72,  78, 121],
#          ...,
#          [ 95, 106, 136],
#          [ 97, 110, 142],
#          [100, 111, 149]],
#
#         [[ 47,  52,  73],
#          [ 61,  62, 100],
#          [ 76,  79, 123],
#          ...,
#          [ 96, 107, 137],
#          [ 98, 111, 143],
#          [103, 114, 152]]],
#
#
#        [[[255, 193, 133],
#          [253, 191, 131],
#          [254, 192, 132],
#          ...,
#          [ 28,  27,  43],
#          [ 22,  23,  33],
#          [ 19,  21,  29]],
#
#         [[250, 187, 129],
#          [255, 194, 136],
#          [255, 194, 136],
#          ...,
#          [ 25,  21,  33],
#          [ 28,  24,  36],
#          [ 34,  30,  42]],
#
#         [[255, 191, 137],
#          [255, 191, 137],
#          [253, 189, 135],
#          ...,
#          [ 37,  29,  40],
#          [ 37,  27,  43],
#          [ 42,  31,  51]],
#
#         ...,
#
#         [[ 66,  58,  45],
#          [ 71,  63,  50],
#          [ 80,  72,  59],
#          ...,
#          [102, 140, 138],
#          [ 80, 114, 113],
#          [ 67,  99,  98]],
#
#         [[ 68,  54,  42],
#          [ 86,  72,  60],
#          [ 86,  72,  60],
#          ...,
#          [ 58,  89,  92],
#          [100, 132, 135],
#          [104, 123, 128]],
#
#         [[135, 113,  88],
#          [121, 100,  78],
#          [118, 101,  82],
#          ...,
#          [130, 153, 169],
#          [111, 141, 160],
#          [110, 136, 148]]]], dtype=uint8)

# %%
x=x/255 #feature scaling for running model in a faster way

# %%
x
# Out:
# array([[[[0.47058824, 0.10980392, 0.03529412],
#          [0.47843137, 0.11764706, 0.04313725],
#          [0.48627451, 0.1254902 , 0.04705882],
#          ...,
#          [0.34901961, 0.0745098 , 0.02352941],
#          [0.35294118, 0.07843137, 0.02745098],
#          [0.35686275, 0.08235294, 0.03137255]],
#
#         [[0.48627451, 0.11764706, 0.04313725],
#          [0.49019608, 0.12156863, 0.04705882],
#          [0.49803922, 0.12941176, 0.05490196],
#          ...,
#          [0.36078431, 0.07843137, 0.03137255],
#          [0.36078431, 0.07843137, 0.03137255],
#          [0.36470588, 0.08235294, 0.03529412]],
#
#         [[0.50196078, 0.12941176, 0.05098039],
#          [0.50588235, 0.13333333, 0.05882353],
#          [0.50980392, 0.1372549 , 0.0627451 ],
#          ...,
#          [0.35686275, 0.06666667, 0.01960784],
#          [0.36078431, 0.0745098 , 0.02352941],
#          [0.36862745, 0.07843137, 0.03137255]],
#
#         ...,
#
#         [[0.50196078, 0.56470588, 0.58823529],
#          [0.52156863, 0.58039216, 0.61176471],
#          [0.50588235, 0.56470588, 0.59607843],
#          ...,
#          [0.50196078, 0.55294118, 0.59215686],
#          [0.4       , 0.44705882, 0.48235294],
#          [0.41960784, 0.46666667, 0.50196078]],
#
#         [[0.47843137, 0.54509804, 0.55686275],
#          [0.37647059, 0.43921569, 0.45882353],
#          [0.39607843, 0.45882353, 0.48627451],
#          ...,
#          [0.51372549, 0.59215686, 0.63529412],
#          [0.48627451, 0.55686275, 0.60392157],
#          [0.41568627, 0.47843137, 0.51372549]],
#
#         [[0.47058824, 0.52941176, 0.54117647],
#          [0.29803922, 0.35294118, 0.37647059],
#          [0.28235294, 0.33333333, 0.36470588],
#          ...,
#          [0.52941176, 0.59215686, 0.63921569],
#          [0.50196078, 0.55686275, 0.60392157],
#          [0.47058824, 0.50980392, 0.55294118]]],
#
#
#        [[[0.22352941, 0.24313725, 0.23921569],
#          [0.22352941, 0.24313725, 0.23921569],
#          [0.21568627, 0.23529412, 0.23137255],
#          ...,
#          [0.23921569, 0.24705882, 0.24705882],
#          [0.24313725, 0.25098039, 0.25098039],
#          [0.24313725, 0.25098039, 0.25098039]],
#
#         [[0.22352941, 0.24313725, 0.23921569],
#          [0.22352941, 0.24313725, 0.23921569],
#          [0.21568627, 0.23529412, 0.23137255],
#          ...,
#          [0.23921569, 0.24705882, 0.24705882],
#          [0.24313725, 0.25098039, 0.25098039],
#          [0.24313725, 0.25098039, 0.25098039]],
#
#         [[0.22352941, 0.24313725, 0.23921569],
#          [0.22352941, 0.24313725, 0.23921569],
#          [0.21176471, 0.23529412, 0.22745098],
#          ...,
#          [0.24705882, 0.25098039, 0.25098039],
#          [0.24313725, 0.25098039, 0.25098039],
#          [0.24313725, 0.25098039, 0.25098039]],
#
#         ...,
#
#         [[0.6627451 , 0.68627451, 0.71372549],
#          [0.63921569, 0.6627451 , 0.69019608],
#          [0.61960784, 0.64313725, 0.67058824],
#          ...,
#          [0.2745098 , 0.3254902 , 0.37647059],
#          [0.2627451 , 0.30588235, 0.34509804],
#          [0.25882353, 0.29803922, 0.32941176]],
#
#         [[0.63137255, 0.65490196, 0.70196078],
#          [0.64705882, 0.67058824, 0.71764706],
#          [0.64313725, 0.66666667, 0.71372549],
#          ...,
#          [0.2627451 , 0.32941176, 0.38431373],
#          [0.26666667, 0.3254902 , 0.37647059],
#          [0.30980392, 0.36470588, 0.40392157]],
#
#         [[0.56470588, 0.59215686, 0.65098039],
#          [0.58823529, 0.61568627, 0.6745098 ],
#          [0.58823529, 0.61960784, 0.6745098 ],
#          ...,
#          [0.25882353, 0.33333333, 0.39215686],
#          [0.29803922, 0.36862745, 0.41960784],
#          [0.29019608, 0.35294118, 0.4       ]]],
#
#
#        [[[0.02745098, 0.02745098, 0.02745098],
#          [0.02745098, 0.02745098, 0.02745098],
#          [0.03137255, 0.03137255, 0.03137255],
#          ...,
#          [0.14901961, 0.16078431, 0.17254902],
#          [0.72156863, 0.69019608, 0.61568627],
#          [0.53333333, 0.49019608, 0.4745098 ]],
#
#         [[0.02745098, 0.02745098, 0.02745098],
#          [0.02745098, 0.02745098, 0.02745098],
#          [0.02745098, 0.02745098, 0.02745098],
#          ...,
#          [0.17254902, 0.18431373, 0.18823529],
#          [0.7254902 , 0.69411765, 0.60784314],
#          [0.54117647, 0.50196078, 0.4745098 ]],
#
#         [[0.02745098, 0.02745098, 0.02745098],
#          [0.02745098, 0.02745098, 0.02745098],
#          [0.02352941, 0.02352941, 0.02352941],
#          ...,
#          [0.19215686, 0.19607843, 0.18823529],
#          [0.67843137, 0.6627451 , 0.56862745],
#          [0.5372549 , 0.50196078, 0.46666667]],
#
#         ...,
#
#         [[0.05882353, 0.08235294, 0.08627451],
#          [0.05882353, 0.0745098 , 0.07843137],
#          [0.05490196, 0.05490196, 0.0627451 ],
#          ...,
#          [0.22745098, 0.22352941, 0.20784314],
#          [0.21176471, 0.2       , 0.18431373],
#          [0.07058824, 0.07843137, 0.07843137]],
#
#         [[0.05882353, 0.07843137, 0.08235294],
#          [0.0627451 , 0.07843137, 0.08235294],
#          [0.0627451 , 0.0627451 , 0.07058824],
#          ...,
#          [0.23137255, 0.22745098, 0.21176471],
#          [0.22745098, 0.21568627, 0.19607843],
#          [0.0627451 , 0.08235294, 0.07843137]],
#
#         [[0.05882353, 0.07843137, 0.08235294],
#          [0.0627451 , 0.07843137, 0.08235294],
#          [0.06666667, 0.06666667, 0.0745098 ],
#          ...,
#          [0.21568627, 0.21176471, 0.19607843],
#          [0.21568627, 0.20392157, 0.18431373],
#          [0.0627451 , 0.08627451, 0.08235294]]],
#
#
#        ...,
#
#
#        [[[0.81960784, 0.54117647, 0.38039216],
#          [0.89411765, 0.67058824, 0.55294118],
#          [0.89803922, 0.63137255, 0.44705882],
#          ...,
#          [0.62352941, 0.66666667, 0.71764706],
#          [0.67843137, 0.68627451, 0.70980392],
#          [0.70588235, 0.70196078, 0.71764706]],
#
#         [[0.81568627, 0.56862745, 0.34901961],
#          [0.90588235, 0.70196078, 0.54509804],
#          [0.81960784, 0.58431373, 0.40392157],
#          ...,
#          [0.6       , 0.61568627, 0.65882353],
#          [0.74509804, 0.70980392, 0.72156863],
#          [0.7372549 , 0.75294118, 0.75686275]],
#
#         [[0.96862745, 0.7372549 , 0.49019608],
#          [0.94117647, 0.72156863, 0.50980392],
#          [0.91764706, 0.69803922, 0.49803922],
#          ...,
#          [0.4       , 0.40392157, 0.44313725],
#          [0.41568627, 0.38431373, 0.40392157],
#          [0.34509804, 0.37647059, 0.39215686]],
#
#         ...,
#
#         [[0.81176471, 0.80784314, 0.84705882],
#          [0.81176471, 0.80784314, 0.84705882],
#          [0.81176471, 0.81176471, 0.85098039],
#          ...,
#          [0.84313725, 0.83529412, 0.85882353],
#          [0.83137255, 0.82352941, 0.84705882],
#          [0.83921569, 0.83137255, 0.85490196]],
#
#         [[0.81568627, 0.81176471, 0.84705882],
#          [0.78823529, 0.78431373, 0.81960784],
#          [0.81176471, 0.81176471, 0.84705882],
#          ...,
#          [0.85098039, 0.85098039, 0.8745098 ],
#          [0.83529412, 0.83137255, 0.85490196],
#          [0.81960784, 0.81568627, 0.83921569]],
#
#         [[0.81176471, 0.80784314, 0.84313725],
#          [0.82352941, 0.81960784, 0.85490196],
#          [0.82745098, 0.82352941, 0.85882353],
#          ...,
#          [0.82352941, 0.82352941, 0.84705882],
#          [0.83921569, 0.83921569, 0.8627451 ],
#          [0.82352941, 0.82352941, 0.84705882]]],
#
#
#        [[[0.19607843, 0.23529412, 0.2745098 ],
#          [0.20392157, 0.24705882, 0.27843137],
#          [0.22745098, 0.2745098 , 0.29019608],
#          ...,
#          [0.05490196, 0.10196078, 0.11764706],
#          [0.10588235, 0.1254902 , 0.14509804],
#          [0.12156863, 0.09803922, 0.14509804]],
#
#         [[0.15686275, 0.19215686, 0.22745098],
#          [0.16470588, 0.20392157, 0.23137255],
#          [0.20392157, 0.25098039, 0.25882353],
#          ...,
#          [0.05098039, 0.09411765, 0.10980392],
#          [0.10588235, 0.12156863, 0.14117647],
#          [0.1372549 , 0.12941176, 0.15294118]],
#
#         [[0.16470588, 0.19607843, 0.22352941],
#          [0.14901961, 0.18431373, 0.2       ],
#          [0.16862745, 0.20784314, 0.20784314],
#          ...,
#          [0.07843137, 0.11372549, 0.12941176],
#          [0.12941176, 0.14117647, 0.16078431],
#          [0.1372549 , 0.1372549 , 0.16078431]],
#
#         ...,
#
#         [[0.17647059, 0.21176471, 0.29019608],
#          [0.23529412, 0.26666667, 0.41176471],
#          [0.26666667, 0.29411765, 0.4627451 ],
#          ...,
#          [0.38431373, 0.42745098, 0.54509804],
#          [0.39215686, 0.44313725, 0.56862745],
#          [0.40784314, 0.45098039, 0.6       ]],
#
#         [[0.19607843, 0.22352941, 0.30196078],
#          [0.25098039, 0.26666667, 0.41568627],
#          [0.28235294, 0.30588235, 0.4745098 ],
#          ...,
#          [0.37254902, 0.41568627, 0.53333333],
#          [0.38039216, 0.43137255, 0.55686275],
#          [0.39215686, 0.43529412, 0.58431373]],
#
#         [[0.18431373, 0.20392157, 0.28627451],
#          [0.23921569, 0.24313725, 0.39215686],
#          [0.29803922, 0.30980392, 0.48235294],
#          ...,
#          [0.37647059, 0.41960784, 0.5372549 ],
#          [0.38431373, 0.43529412, 0.56078431],
#          [0.40392157, 0.44705882, 0.59607843]]],
#
#
#        [[[1.        , 0.75686275, 0.52156863],
#          [0.99215686, 0.74901961, 0.51372549],
#          [0.99607843, 0.75294118, 0.51764706],
#          ...,
#          [0.10980392, 0.10588235, 0.16862745],
#          [0.08627451, 0.09019608, 0.12941176],
#          [0.0745098 , 0.08235294, 0.11372549]],
#
#         [[0.98039216, 0.73333333, 0.50588235],
#          [1.        , 0.76078431, 0.53333333],
#          [1.        , 0.76078431, 0.53333333],
#          ...,
#          [0.09803922, 0.08235294, 0.12941176],
#          [0.10980392, 0.09411765, 0.14117647],
#          [0.13333333, 0.11764706, 0.16470588]],
#
#         [[1.        , 0.74901961, 0.5372549 ],
#          [1.        , 0.74901961, 0.5372549 ],
#          [0.99215686, 0.74117647, 0.52941176],
#          ...,
#          [0.14509804, 0.11372549, 0.15686275],
#          [0.14509804, 0.10588235, 0.16862745],
#          [0.16470588, 0.12156863, 0.2       ]],
#
#         ...,
#
#         [[0.25882353, 0.22745098, 0.17647059],
#          [0.27843137, 0.24705882, 0.19607843],
#          [0.31372549, 0.28235294, 0.23137255],
#          ...,
#          [0.4       , 0.54901961, 0.54117647],
#          [0.31372549, 0.44705882, 0.44313725],
#          [0.2627451 , 0.38823529, 0.38431373]],
#
#         [[0.26666667, 0.21176471, 0.16470588],
#          [0.3372549 , 0.28235294, 0.23529412],
#          [0.3372549 , 0.28235294, 0.23529412],
#          ...,
#          [0.22745098, 0.34901961, 0.36078431],
#          [0.39215686, 0.51764706, 0.52941176],
#          [0.40784314, 0.48235294, 0.50196078]],
#
#         [[0.52941176, 0.44313725, 0.34509804],
#          [0.4745098 , 0.39215686, 0.30588235],
#          [0.4627451 , 0.39607843, 0.32156863],
#          ...,
#          [0.50980392, 0.6       , 0.6627451 ],
#          [0.43529412, 0.55294118, 0.62745098],
#          [0.43137255, 0.53333333, 0.58039216]]]])

# %%
x.shape
# Out:
# (66, 100, 100, 3)

# %%
#data augmentaion

# %%
dataGen = ImageDataGenerator(width_shift_range=0.1,
                             height_shift_range=0.1,
                             zoom_range=0.2,
                             shear_range=0.1,
                             rotation_range=20,
                             horizontal_flip= True)

# %%
pip install keras-tuner
# Out:
# Requirement already satisfied: keras-tuner in c:\users\asus\.conda\envs\tensorflow\lib\site-packages (1.0.1)
# Requirement already satisfied: requests in c:\users\asus\.conda\envs\tensorflow\lib\site-packages (from keras-tuner) (2.24.0)
# Requirement already satisfied: tabulate in c:\users\asus\.conda\envs\tensorflow\lib\site-packages (from keras-tuner) (0.8.7)
# Requirement already satisfied: tqdm in c:\users\asus\.conda\envs\tensorflow\lib\site-packages (from keras-tuner) (4.50.2)
# Requirement already satisfied: scipy in c:\users\asus\.conda\envs\tensorflow\lib\site-packages (from keras-tuner) (1.5.2)
# Requirement already satisfied: future in c:\users\asus\.conda\envs\tensorflow\lib\site-packages (from keras-tuner) (0.18.2)
# Requirement already satisfied: scikit-learn in c:\users\asus\.conda\envs\tensorflow\lib\site-packages (from keras-tuner) (0.23.2)
# Requirement already satisfied: colorama in c:\users\asus\.conda\envs\tensorflow\lib\site-packages (from keras-tuner) (0.4.3)
# Requirement already satisfied: terminaltables in c:\users\asus\.conda\envs\tensorflow\lib\site-packages (from keras-tuner) (3.1.0)
# Requirement already satisfied: numpy in c:\users\asus\.conda\envs\tensorflow\lib\site-packages (from keras-tuner) (1.19.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\asus\.conda\envs\tensorflow\lib\site-packages (from requests->keras-tuner) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\asus\.conda\envs\tensorflow\lib\site-packages (from requests->keras-tuner) (1.25.10)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\asus\.conda\envs\tensorflow\lib\site-packages (from requests->keras-tuner) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\.conda\envs\tensorflow\lib\site-packages (from requests->keras-tuner) (2020.6.20)
# Requirement already satisfied: joblib>=0.11 in c:\users\asus\.conda\envs\tensorflow\lib\site-packages (from scikit-learn->keras-tuner) (0.17.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\asus\.conda\envs\tensorflow\lib\site-packages (from scikit-learn->keras-tuner) (2.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
print(tf.__version__)
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout, Activation, Flatten, Conv2D, MaxPooling2D
# Out:
# 2.1.0

# %%
x[0]
# Out:
# array([[[0.47058824, 0.10980392, 0.03529412],
#         [0.47843137, 0.11764706, 0.04313725],
#         [0.48627451, 0.1254902 , 0.04705882],
#         ...,
#         [0.34901961, 0.0745098 , 0.02352941],
#         [0.35294118, 0.07843137, 0.02745098],
#         [0.35686275, 0.08235294, 0.03137255]],
#
#        [[0.48627451, 0.11764706, 0.04313725],
#         [0.49019608, 0.12156863, 0.04705882],
#         [0.49803922, 0.12941176, 0.05490196],
#         ...,
#         [0.36078431, 0.07843137, 0.03137255],
#         [0.36078431, 0.07843137, 0.03137255],
#         [0.36470588, 0.08235294, 0.03529412]],
#
#        [[0.50196078, 0.12941176, 0.05098039],
#         [0.50588235, 0.13333333, 0.05882353],
#         [0.50980392, 0.1372549 , 0.0627451 ],
#         ...,
#         [0.35686275, 0.06666667, 0.01960784],
#         [0.36078431, 0.0745098 , 0.02352941],
#         [0.36862745, 0.07843137, 0.03137255]],
#
#        ...,
#
#        [[0.50196078, 0.56470588, 0.58823529],
#         [0.52156863, 0.58039216, 0.61176471],
#         [0.50588235, 0.56470588, 0.59607843],
#         ...,
#         [0.50196078, 0.55294118, 0.59215686],
#         [0.4       , 0.44705882, 0.48235294],
#         [0.41960784, 0.46666667, 0.50196078]],
#
#        [[0.47843137, 0.54509804, 0.55686275],
#         [0.37647059, 0.43921569, 0.45882353],
#         [0.39607843, 0.45882353, 0.48627451],
#         ...,
#         [0.51372549, 0.59215686, 0.63529412],
#         [0.48627451, 0.55686275, 0.60392157],
#         [0.41568627, 0.47843137, 0.51372549]],
#
#        [[0.47058824, 0.52941176, 0.54117647],
#         [0.29803922, 0.35294118, 0.37647059],
#         [0.28235294, 0.33333333, 0.36470588],
#         ...,
#         [0.52941176, 0.59215686, 0.63921569],
#         [0.50196078, 0.55686275, 0.60392157],
#         [0.47058824, 0.50980392, 0.55294118]]])

# %%
x[0].shape
# Out:
# (100, 100, 3)

# %%
model= Sequential()
model.add(Conv2D(64, (3,3),input_shape=x.shape[1:], activation= 'relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(64,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(128,input_shape=x.shape[1:], activation='relu'))

model.add(Dense(2,activation='softmax'))

# %%
model.compile(loss="sparse_categorical_crossentropy",
             optimizer ="adam",
             metrics =['accuracy'])

# %%
model.fit(x,y, epochs=20,validation_split=0.1)
# Out:
# Train on 59 samples, validate on 7 samples
# Epoch 1/20
# 59/59 [==============================] - 3s 45ms/sample - loss: 2.6498 - accuracy: 0.6102 - val_loss: 0.6318 - val_accuracy: 0.7143
# Epoch 2/20
# 59/59 [==============================] - 1s 18ms/sample - loss: 1.0064 - accuracy: 0.5424 - val_loss: 1.1632 - val_accuracy: 0.2857
# Epoch 3/20
# 59/59 [==============================] - 1s 19ms/sample - loss: 0.9318 - accuracy: 0.3729 - val_loss: 0.7255 - val_accuracy: 0.2857
# Epoch 4/20
# 59/59 [==============================] - 1s 19ms/sample - loss: 0.6896 - accuracy: 0.4407 - val_loss: 0.5469 - val_accuracy: 0.7143
# Epoch 5/20
# 59/59 [==============================] - 1s 20ms/sample - loss: 0.6705 - accuracy: 0.6271 - val_loss: 0.5516 - val_accuracy: 0.7143
# Epoch 6/20
# 59/59 [==============================] - 1s 19ms/sample - loss: 0.6235 - accuracy: 0.6271 - val_loss: 0.6110 - val_accuracy: 0.7143
# Epoch 7/20
# 59/59 [==============================] - 1s 19ms/sample - loss: 0.6029 - accuracy: 0.6441 - val_loss: 0.5585 - val_accuracy: 0.7143
# Epoch 8/20
# 59/59 [==============================] - 1s 20ms/sample - loss: 0.5482 - accuracy: 0.6610 - val_loss: 0.5479 - val_accuracy: 0.7143
# Epoch 9/20
# 59/59 [==============================] - 1s 19ms/sample - loss: 0.4863 - accuracy: 0.7966 - val_loss: 0.5313 - val_accuracy: 0.7143
# Epoch 10/20
# 59/59 [==============================] - 1s 18ms/sample - loss: 0.4066 - accuracy: 0.7627 - val_loss: 0.6377 - val_accuracy: 0.7143
# Epoch 11/20
# 59/59 [==============================] - 1s 19ms/sample - loss: 0.3511 - accuracy: 1.0000 - val_loss: 0.4717 - val_accuracy: 0.7143
# Epoch 12/20
# 59/59 [==============================] - 1s 19ms/sample - loss: 0.3921 - accuracy: 0.7797 - val_loss: 0.4830 - val_accuracy: 0.7143
# Epoch 13/20
# 59/59 [==============================] - 1s 19ms/sample - loss: 0.2713 - accuracy: 1.0000 - val_loss: 0.7303 - val_accuracy: 0.4286
# Epoch 14/20
# 59/59 [==============================] - 1s 19ms/sample - loss: 0.2742 - accuracy: 0.9831 - val_loss: 0.5288 - val_accuracy: 0.8571
# Epoch 15/20
# 59/59 [==============================] - 1s 18ms/sample - loss: 0.1977 - accuracy: 0.9831 - val_loss: 0.5751 - val_accuracy: 0.7143
# Epoch 16/20
# 59/59 [==============================] - 1s 18ms/sample - loss: 0.1587 - accuracy: 0.9661 - val_loss: 0.5466 - val_accuracy: 0.7143
# Epoch 17/20
# 59/59 [==============================] - 1s 18ms/sample - loss: 0.1070 - accuracy: 1.0000 - val_loss: 0.5237 - val_accuracy: 0.7143
# Epoch 18/20
# 59/59 [==============================] - 1s 18ms/sample - loss: 0.0608 - accuracy: 1.0000 - val_loss: 0.6379 - val_accuracy: 0.7143
# Epoch 19/20
# 59/59 [==============================] - 1s 19ms/sample - loss: 0.0612 - accuracy: 1.0000 - val_loss: 0.5992 - val_accuracy: 0.8571
# Epoch 20/20
# 59/59 [==============================] - 1s 18ms/sample - loss: 0.0355 - accuracy: 1.0000 - val_loss: 0.5996 - val_accuracy: 0.5714

# %%
model_name="cat_and_dog_own_data_four.h5"
model.save(model_name)

# %%
from tensorflow.keras.models import load_model
load_model(model_name)

# %%
from keras.preprocessing import image
import numpy as np

img_pred=image.load_img(r"C:\Users\Asus\own_dataset\dog\dog.7306.jpg",target_size=(100,100))

img_pred=image.img_to_array(img_pred)
img_pred=np.expand_dims(img_pred, axis=0)
rslt= model.predict(img_pred)

print(rslt)
if rslt[0][0]>rslt[0][1]:
    prediction="cat"
    
    
else:
    prediction="dog"
print(prediction)
# Out:
# [[0. 1.]]
# dog

# %%
#checking my main model size

# %%
import os
def get_file_size(file_path):
    size= os.path.getsize(file_path)
    return size
def convert_bytes(size, unit=None):
    if unit== "KB":
        return print ('File size:' +str(round(size/1024,3)) +'kilobytes')
    elif unit=="MB":
         return print ('File size:' +str(round(size/(1024*1024),3)) +'Megabytes')
    else:
         return print ('File size:' +str(size) +'bytes')
convert_bytes(get_file_size(model_name),"MB")
# Out:
# File size:50.081Megabytes

# %%
tf_lite_model="second_tflite.tflite"

# %%
tf_lite_converter=tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model=tf_lite_converter.convert()

# %%
#save the model in memory

# %%
tflite_model_name= tf_lite_model
open(tflite_model_name, "wb").write(tflite_model)
# Out:
# 17493072

# %%
convert_bytes(get_file_size(tf_lite_model),"MB")
# Out:
# File size:16.683Megabytes

# %%
#evaluate my tflite mode;

# %%
interpreter =tf.lite.Interpreter(model_path=tf_lite_model)
input_details=interpreter.get_input_details()
output_details=interpreter.get_output_details()
print("input shape:",input_details[0]['shape'])
print("input type:",input_details[0]['dtype'])
print("output shape:",output_details[0]['shape'])
print("output shape:",output_details[0]['dtype'])
# Out:
# input shape: [  1 100 100   3]
# input type: <class 'numpy.float32'>
# output shape: [1 2]
# output shape: <class 'numpy.float32'>

# %%
#making quantized model

# %%
tf_lite_model_quantized="second_quantized_tflite.tflite"

# %%
tf_lite_converter=tf.lite.TFLiteConverter.from_keras_model(model)

tf_lite_converter.optimizations=[tf.lite.Optimize.DEFAULT]
tf_lite_converter.target_spec.supported_types=[tf.float16]
tflite_model=tf_lite_converter.convert()

# %%
print (tf.__version__)
# Out:
# 2.1.0

# %%
tflite_model_name= tf_lite_model_quantized
open(tflite_model_name, "wb").write(tflite_model)
# Out:
# 8748700

# %%
convert_bytes(get_file_size(tf_lite_model_quantized),"MB")
# Out:
# File size:8.343Megabytes
